# %% [markdown]
# HF Course Notebook
# │
#
# ├── Section 1: Install
#
# ├── Section 2: Authentication
#
# ├── Section 3: Imports
#
# ├── Section 4: Model
#
# ├── Section 5: Tools
#
# ├── Section 6: Agent
#
# └── Section 7: Experiments

# %% [markdown]
# # Installation

# %%
# !pip -q install smolagents
# !pip -q install huggingface_hub
# !pip -q install litellm
# !pip -q install openai
# !pip -q install langfuse
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.6/562.6 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 5.6 MB/s eta 0:00:00

# %%
# !pip -q install smolagents litellm

# %% [markdown]
# ### Extra package

# %%
# !pip -q install duckduckgo-search
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 44.8 MB/s eta 0:00:00

# %% [markdown]
# # Authentication

# %%
from getpass import getpass
import os
if "HF_TOKEN" not in os.environ:
    os.environ["HF_TOKEN"] = getpass("Enter HF Token: ")
if "LANGFUSE_PUBLIC_KEY" not in os.environ:
    os.environ["LANGFUSE_PUBLIC_KEY"] = "pk-lf-4f064140-e28b-4c90-9ee1-0ed0d7b0662a"

if "LANGFUSE_SECRET_KEY" not in os.environ:
    os.environ["LANGFUSE_SECRET_KEY"] = getpass("Langfuse Secret Key: ")
# Out:
# Langfuse Secret Key: ··········

# %%
from getpass import getpass
import os

if "GEMINI_API_KEY" not in os.environ:
    os.environ["GEMINI_API_KEY"] = getpass("gemini API Key: ")
# Out:
# gemini API Key: ··········

# %% [markdown]
# # Imports

# %%
from smolagents import (
    CodeAgent,
    ToolCallingAgent,
    tool,
    OpenAIModel,
    LiteLLMModel
)

# %%
from huggingface_hub import login
import os

# %% [markdown]
# # Models

# %%
model = LiteLLMModel(
    model_id="gemini/gemini-2.5-flash",
    api_key=os.environ["GEMINI_API_KEY"]
)

# %%
print(model)
# Out:
# <smolagents.models.LiteLLMModel object at 0x7b7ae3f4a990>

# %% [markdown]
# # Tools

# %%
@tool
def add(a:int, b:int) -> int:
    """
    Adds two numbers.

    Args:
        a (int): The first number.
        b (int): The second number.
    """
    return a+b

# %%
@tool
def multiply(a:int, b:int) -> int:
    """
    Multiplies two numbers.

    Args:
        a (int): The first number.
        b (int): The second number.
    """
    return a*b

# %% [markdown]
# # Agents

# %%
agent = CodeAgent(
    tools=[add, multiply],
    model=model
)

# %% [markdown]
# # Experiments

# %%
agent.run("2+2=?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 2+2=?                                                                                                           │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.5-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = add(a=2, b=2)
#   final_answer(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 4
# [Step 1: Duration 1.76 seconds| Input tokens: 2,243 | Output tokens: 46]
# 4
